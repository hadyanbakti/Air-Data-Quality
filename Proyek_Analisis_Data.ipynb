# %% [markdown]
# # Proyek Analisis Data: [Aur Quality Dataset]
# - **Nama:** Hadyan Baktiadi
# - **Email:** hadyan.bakti@gmail.com
# - **ID Dicoding:** hadyan_baktiadi

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana korelasi antara suhu (TEMP) dengan tingkat polutan utama (PM2.5, PM10, SO2, NO2, CO, O3)?
# - Apakah ada perbedaan signifikan dalam tingkat polutan antara hari kerja dan akhir pekan?
# - Bagaimana tren tahunan tingkat rata-rata CO di berbagai kota dari 2013 hingga 2017 dan apakah ada pola umum yang terlihat?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import streamlit as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %matplotlib inline

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
df_Aotizhongxin = pd.read_csv("air-quality-dataset/PRSA_Data_Aotizhongxin_20130301-20170228.csv")
df_Changping = pd.read_csv("air-quality-dataset/PRSA_Data_Changping_20130301-20170228.csv"
    )
df_Dingling = pd.read_csv(
        "air-quality-dataset/PRSA_Data_Dingling_20130301-20170228.csv"
    )
df_Dongsi = pd.read_csv(
        "air-quality-dataset/PRSA_Data_Dongsi_20130301-20170228.csv"
    )
df_Guanyuan = pd.read_csv(
        "air-quality-dataset/PRSA_Data_Guanyuan_20130301-20170228.csv"
    )
df_Gucheng = pd.read_csv(
        "air-quality-dataset/PRSA_Data_Gucheng_20130301-20170228.csv"
    )
df_Huairou = pd.read_csv(
        "air-quality-dataset/PRSA_Data_Huairou_20130301-20170228.csv"
    )
df_Nongzhanguan = pd.read_csv(
        "air-quality-dataset/PRSA_Data_Nongzhanguan_20130301-20170228.csv"
    )
df_Shunyi = pd.read_csv(
        "air-quality-dataset/PRSA_Data_Shunyi_20130301-20170228.csv"
    )
df_Tiantan = pd.read_csv(
        "air-quality-dataset/PRSA_Data_Tiantan_20130301-20170228.csv"
    )
df_Wanliu = pd.read_csv(
        "air-quality-dataset/PRSA_Data_Wanliu_20130301-20170228.csv"
    )
df_Wanshouxigong = pd.read_csv(
        "air-quality-dataset/PRSA_Data_Wanshouxigong_20130301-20170228.csv"
    )

# %% [markdown]
# head of Aotizhangxin

# %%
df_Aotizhongxin.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# head of Changping

# %% [markdown]
# head of Changping

# %%
df_Changping.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %% [markdown]
# head of Dingling

# %%
df_Dingling.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %% [markdown]
# head of Dongsi

# %%
df_Dongsi.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %% [markdown]
# head Of Guanyuan

# %%
df_Guanyuan.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %% [markdown]
# head Of Gucheng

# %%
df_Gucheng.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %% [markdown]
# head Of Huairou

# %%
df_Huairou.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %% [markdown]
# head of Nongzhanguan

# %%
df_Nongzhanguan.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %% [markdown]
# head of Shunyi

# %%
df_Shunyi.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %% [markdown]
# head of Tiantan

# %%
df_Tiantan.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %% [markdown]
# head of Wanliu

# %%
df_Wanliu.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %% [markdown]
# head of Wanshouxigong

# %%
df_Wanshouxigong.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# mencari missing value

# %%
print('Dataframe Aotizhongxin:')
print(df_Aotizhongxin.isna().sum())
print('\nDataframe Changping:')
print(df_Changping.isna().sum())
print('\nDataframe Dingling:')
print(df_Dingling.isna().sum())
print('\nDataframe Dongsi:')
print(df_Dongsi.isna().sum())
print('\nDataframe Guanyuan:')
print(df_Guanyuan.isna().sum())
print('\nDataframe Gucheng:')
print(df_Gucheng.isna().sum())
print('\nDataframe Gucheng:')
print(df_Aotizhongxin.isna().sum())
print('\nDataframe Huairou:')
print(df_Huairou.isna().sum())
print('\nDataframe Nongzhanguan:')
print(df_Nongzhanguan.isna().sum())
print('\nDataframe Shunyi:')
print(df_Shunyi.isna().sum())
print('\nDataframe Tiantan:')
print(df_Tiantan.isna().sum())
print('\nDataframe Wanliu:')
print(df_Wanliu.isna().sum())
print('\nDataframe Wanshouxigong:')
print(df_Wanliu.isna().sum())
# Out:
# Dataframe Aotizhongxin:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64
#
# Dataframe Changping:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64
#
# Dataframe Dingling:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# ...

# %% [markdown]
# **insight :**
# -  masing masing data memiliki missing value pada kolom masing-masing, sehingga diperlukan untuk melakukan pembersihan data

# %% [markdown]
# mencari duplikat value

# %%
print('Data Duplikat:')
print('Dataframe Aotizhongxin:', df_Aotizhongxin.duplicated().sum())
print('Dataframe Changping:', df_Changping.duplicated().sum())
print('Dataframe Dingling:', df_Dingling.duplicated().sum())
print('Dataframe Dongsi:', df_Dongsi.duplicated().sum())
print('Dataframe Guanyuan:', df_Guanyuan.duplicated().sum())
print('Dataframe Gucheng:', df_Gucheng.duplicated().sum())
print('Dataframe Huairou:', df_Huairou.duplicated().sum())
print('Dataframe Nongzhanguan:', df_Nongzhanguan.duplicated().sum())
print('Dataframe Shunyi:', df_Shunyi.duplicated().sum())
print('Dataframe Tiantan:', df_Tiantan.duplicated().sum())
print('Dataframe Wanliu:', df_Wanliu.duplicated().sum())
print('Dataframe Wanshouxigong:', df_Wanshouxigong.duplicated().sum())
# Out:
# Data Duplikat:
# Dataframe Aotizhongxin: 0
# Dataframe Changping: 0
# Dataframe Dingling: 0
# Dataframe Dongsi: 0
# Dataframe Guanyuan: 0
# Dataframe Gucheng: 0
# Dataframe Huairou: 0
# Dataframe Nongzhanguan: 0
# Dataframe Shunyi: 0
# Dataframe Tiantan: 0
# Dataframe Wanliu: 0
# Dataframe Wanshouxigong: 0

# %% [markdown]
# **Insight:**
# - tidak ada data yang mempunyai duplikat

# %% [markdown]
# Cek outlier pada data

# %%
def outliers_iqr(df):
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    IQR = Q3 - Q1
    return ((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)

outliers_Aotizhongxin_iqr = outliers_iqr(df_Aotizhongxin.select_dtypes(include=[np.number]))
outliers_Changping_iqr = outliers_iqr(df_Changping.select_dtypes(include=[np.number]))
outliers_Dingling_iqr = outliers_iqr(df_Dingling.select_dtypes(include=[np.number]))
outliers_Dongsi_iqr = outliers_iqr(df_Dongsi.select_dtypes(include=[np.number]))
outliers_Guanyuan_iqr = outliers_iqr(df_Guanyuan.select_dtypes(include=[np.number]))
outliers_Gucheng_iqr = outliers_iqr(df_Gucheng.select_dtypes(include=[np.number]))
outliers_Huairou_iqr = outliers_iqr(df_Huairou.select_dtypes(include=[np.number]))
outliers_Nongzhanguan_iqr = outliers_iqr(df_Nongzhanguan.select_dtypes(include=[np.number]))
outliers_Shunyi_iqr = outliers_iqr(df_Shunyi.select_dtypes(include=[np.number]))
outliers_Tiantan_iqr = outliers_iqr(df_Tiantan.select_dtypes(include=[np.number]))
outliers_Wanliu_iqr = outliers_iqr(df_Wanliu.select_dtypes(include=[np.number]))
outliers_Wanshouxigong_iqr = outliers_iqr(df_Wanshouxigong.select_dtypes(include=[np.number]))


print("Outliers in df_Aotizhongxin (IQR):\n", df_Aotizhongxin[outliers_Aotizhongxin_iqr])
print("Outliers in df_Changping (IQR):\n", df_Changping[outliers_Changping_iqr])
print("Outliers in df_Dingling (IQR):\n", df_Dingling[outliers_Dingling_iqr])
print("Outliers in df_Dongsi (IQR):\n", df_Dongsi[outliers_Dongsi_iqr])
print("Outliers in df_Guanyuan (IQR):\n", df_Guanyuan[outliers_Guanyuan_iqr])
print("Outliers in df_Gucheng (IQR):\n", df_Gucheng[outliers_Gucheng_iqr])
print("Outliers in df_Huairou (IQR):\n", df_Huairou[outliers_Huairou_iqr])
print("Outliers in df_Nongzhanguan (IQR):\n", df_Nongzhanguan[outliers_Nongzhanguan_iqr])
print("Outliers in df_Shunyi (IQR):\n", df_Shunyi[outliers_Shunyi_iqr])
print("Outliers in df_Tiantan (IQR):\n", df_Tiantan[outliers_Tiantan_iqr])
print("Outliers in df_Wanliu (IQR):\n", df_Wanliu[outliers_Wanliu_iqr])
print("Outliers in df_Wanshouxigong (IQR):\n", df_Wanshouxigong[outliers_Wanshouxigong_iqr])
# Out:
# Outliers in df_Aotizhongxin (IQR):
#            No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0  4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0  4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0  5.0  10.0  300.0  73.0
# 12        13  2013      3    1    12    3.0   6.0  7.0  13.0  300.0  74.0
# 13        14  2013      3    1    13    3.0   6.0  7.0  12.0  400.0  76.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 34891  34892  2017      2   21    19   31.0  41.0  2.0  48.0  600.0  48.0
# 34892  34893  2017      2   21    20   47.0  52.0  2.0  50.0  800.0  38.0
# 34893  34894  2017      2   21    21   67.0  67.0  2.0  57.0  100.0  21.0
# 34894  34895  2017      2   21    22   60.0  60.0  2.0  47.0  900.0  32.0
# 34895  34896  2017      2   21    23   62.0  62.0  2.0  48.0  100.0  28.0
#
# ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# membersihkan data kosong

# %% [markdown]
# Karena semua data kosong adalah numerik (kecuali pada wd), maka saya menggunakan interpolation dengan value wd tertinggi, langkah yang pertama adalah mencari tau pada masing masing wilayah value wd tertinggi

# %%
print("Aotizhongxin", df_Aotizhongxin['wd'].value_counts())
print("\nChangping",df_Changping['wd'].value_counts() )
print("\nDingling", df_Dingling['wd'].value_counts())
print("\nDongsi", df_Dongsi['wd'].value_counts())
print("\nGuanyuan", df_Guanyuan['wd'].value_counts())
print("\nGucheng", df_Gucheng['wd'].value_counts())
print("\nHuairou", df_Huairou['wd'].value_counts())
print("\nNongzhanguan", df_Nongzhanguan['wd'].value_counts())
print("\nShunyi", df_Shunyi['wd'].value_counts())
print("\nTiantan", df_Tiantan['wd'].value_counts())
print("\nWanliu", df_Wanliu['wd'].value_counts())
print("\nWanshouxigong", df_Wanshouxigong['wd'].value_counts())
# Out:
# Aotizhongxin wd
# NE     5140
# ENE    3950
# SW     3359
# E      2608
# NNE    2445
# WSW    2212
# SSW    2098
# N      2066
# NW     1860
# ESE    1717
# NNW    1589
# SE     1341
# S      1304
# W      1171
# WNW    1101
# SSE    1022
# Name: count, dtype: int64
#
# Changping wd
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: count, dtype: int64
#
# Dingling wd
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: count, dtype: int64
#
# Dongsi wd
# ENE    3861
# E      3564
# NE     3540
# ESE    2706
# SW     2481
# NW     2466
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# ...

# %%
df_Aotizhongxin = df_Aotizhongxin.interpolate(method='linear')
df_Aotizhongxin['wd'].fillna(value='NE', inplace=True)
df_Aotizhongxin.isna().sum()
# Out:
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\1166351294.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_Aotizhongxin = df_Aotizhongxin.interpolate(method='linear')
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\1166351294.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Aotizhongxin['wd'].fillna(value='NE', inplace=True)
# No         0
# year       0
# ...

# %%
df_Changping = df_Changping.interpolate(method='linear')
df_Changping['wd'].fillna(value='NNW', inplace=True)
df_Changping.isna().sum()
# Out:
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\1193785190.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_Changping = df_Changping.interpolate(method='linear')
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\1193785190.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Changping['wd'].fillna(value='NNW', inplace=True)
# No         0
# year       0
# month      0
# ...

# %%
df_Dingling = df_Dingling.interpolate(method='linear')
df_Dingling['wd'].fillna(value='NNW', inplace=True)
df_Dingling.isna().sum()
# Out:
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\2210704637.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_Dingling = df_Dingling.interpolate(method='linear')
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\2210704637.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Dingling['wd'].fillna(value='NNW', inplace=True)
# No         0
# year       0
# month      0
# ...

# %% [markdown]
# karena masih ada data kosong, maka kita bersihkan terlebih dahulu dengan memisahkan kolom numerik dan non numerik, lalu mengisi NaN dengan mean di kolom numerik

# %%
numerik_kolom_Dingling = df_Dingling.select_dtypes(include=[np.number])
kolom_non_numerik_Dingling = df_Dingling.select_dtypes(exclude=[np.number])
numerik_kolom_Dingling.fillna(numerik_kolom_Dingling.mean(), inplace=True)
df_Dingling = pd.concat([numerik_kolom_Dingling, kolom_non_numerik_Dingling], axis=1)
df_Dingling.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# WSPM       0
# wd         0
# station    0
# dtype: int64

# %%
df_Dongsi = df_Dongsi.interpolate(method='linear')
df_Dongsi['wd'].fillna(value='ENE', inplace=True)
df_Dongsi.isna().sum()
# Out:
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\3072190713.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_Dongsi = df_Dongsi.interpolate(method='linear')
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\3072190713.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Dongsi['wd'].fillna(value='ENE', inplace=True)
# No         0
# year       0
# month      0
# ...

# %%
df_Guanyuan = df_Guanyuan.interpolate(method='linear')
df_Guanyuan['wd'].fillna(value='NE', inplace=True)
df_Guanyuan.isna().sum()
# Out:
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\2889977126.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_Guanyuan = df_Guanyuan.interpolate(method='linear')
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\2889977126.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Guanyuan['wd'].fillna(value='NE', inplace=True)
# No         0
# year       0
# month      0
# ...

# %%
df_Gucheng = df_Gucheng.interpolate(method='linear')
df_Gucheng['wd'].fillna(value='N', inplace=True)
df_Gucheng.isna().sum()
# Out:
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\3837667362.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_Gucheng = df_Gucheng.interpolate(method='linear')
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\3837667362.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Gucheng['wd'].fillna(value='N', inplace=True)
# No          0
# year        0
# month       0
# ...

# %% [markdown]
# karena masih ada data kosong, maka kita bersihkan terlebih dahulu dengan memisahkan kolom numerik dan non numerik, lalu mengisi NaN dengan mean di kolom numerik

# %%
numerik_kolom_Gucheng = df_Gucheng.select_dtypes(include=[np.number])
kolom_non_numerik_Gucheng = df_Gucheng.select_dtypes(exclude=[np.number])
numerik_kolom_Gucheng.fillna(numerik_kolom_Gucheng.mean(), inplace=True)
df_Gucheng = pd.concat([numerik_kolom_Gucheng, kolom_non_numerik_Gucheng], axis=1)
df_Gucheng.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# WSPM       0
# wd         0
# station    0
# dtype: int64

# %%
df_Huairou = df_Huairou.interpolate(method='linear')
df_Huairou['wd'].fillna(value='NW', inplace=True)
df_Huairou.isna().sum()
# Out:
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\2870774772.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_Huairou = df_Huairou.interpolate(method='linear')
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\2870774772.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Huairou['wd'].fillna(value='NW', inplace=True)
# No         0
# year       0
# month      0
# ...

# %%
df_Nongzhanguan = df_Nongzhanguan.interpolate(method='linear')
df_Nongzhanguan['wd'].fillna(value='ENE', inplace=True)
df_Nongzhanguan.isna().sum()
# Out:
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\1821676419.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_Nongzhanguan = df_Nongzhanguan.interpolate(method='linear')
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\1821676419.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Nongzhanguan['wd'].fillna(value='ENE', inplace=True)
# No         0
# year       0
# ...

# %%
df_Shunyi = df_Shunyi.interpolate(method='linear')
df_Shunyi['wd'].fillna(value='NNE', inplace=True)
df_Shunyi.isna().sum()
# Out:
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\2544401292.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_Shunyi = df_Shunyi.interpolate(method='linear')
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\2544401292.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Shunyi['wd'].fillna(value='NNE', inplace=True)
# No         0
# year       0
# month      0
# ...

# %%
df_Tiantan = df_Tiantan.interpolate(method='linear')
df_Tiantan['wd'].fillna(value='ENE', inplace=True)
df_Tiantan.isna().sum()
# Out:
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\4267174380.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_Tiantan = df_Tiantan.interpolate(method='linear')
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\4267174380.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Tiantan['wd'].fillna(value='ENE', inplace=True)
# No         0
# year       0
# month      0
# ...

# %%
df_Wanliu = df_Wanliu.interpolate(method='linear')
df_Wanliu['wd'].fillna(value='NE', inplace=True)
df_Wanliu.isna().sum()
# Out:
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\1454777228.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_Wanliu = df_Wanliu.interpolate(method='linear')
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\1454777228.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Wanliu['wd'].fillna(value='NE', inplace=True)
# No         0
# year       0
# month      0
# ...

# %%
df_Wanshouxigong = df_Wanshouxigong.interpolate(method='linear')
df_Wanshouxigong['wd'].fillna(value='NE', inplace=True)
df_Wanshouxigong.isna().sum()
# Out:
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\2834460200.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_Wanshouxigong = df_Wanshouxigong.interpolate(method='linear')
# C:\Users\MSI GF63\AppData\Local\Temp\ipykernel_17412\2834460200.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_Wanshouxigong['wd'].fillna(value='NE', inplace=True)
# No         0
# year       0
# ...

# %% [markdown]
# Bersihkan data dari outlier

# %%
def cap_outliers_iqr(df):
    # Separate numeric and non-numeric columns
    numeric_df = df.select_dtypes(include=[np.number])
    non_numeric_df = df.select_dtypes(exclude=[np.number])

    # Calculate Q1, Q3, and IQR for numeric columns
    Q1 = numeric_df.quantile(0.25)
    Q3 = numeric_df.quantile(0.75)
    IQR = Q3 - Q1

    # Calculate the lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Cap the numeric columns
    capped_numeric_df = numeric_df.apply(
        lambda x: np.where(x < lower_bound[x.name], lower_bound[x.name], 
                           np.where(x > upper_bound[x.name], upper_bound[x.name], x))
    )

    # Convert back to DataFrame and retain column names
    capped_numeric_df = pd.DataFrame(capped_numeric_df, columns=numeric_df.columns)

    # Concatenate numeric and non-numeric columns back together
    df_cleaned = pd.concat([non_numeric_df.reset_index(drop=True), capped_numeric_df.reset_index(drop=True)], axis=1)

    return df_cleaned

# Apply to each DataFrame while retaining all columns
df_Aotizhongxin_clean = cap_outliers_iqr(df_Aotizhongxin)
df_Changping_clean = cap_outliers_iqr(df_Changping)
df_Dingling_clean = cap_outliers_iqr(df_Dingling)
df_Dongsi_clean = cap_outliers_iqr(df_Dongsi)
df_Guanyuan_clean = cap_outliers_iqr(df_Guanyuan)
df_Gucheng_clean = cap_outliers_iqr(df_Gucheng)
df_Huairou_clean = cap_outliers_iqr(df_Huairou)
df_Nongzhanguan_clean = cap_outliers_iqr(df_Nongzhanguan)
df_Shunyi_clean = cap_outliers_iqr(df_Shunyi)
df_Tiantan_clean = cap_outliers_iqr(df_Tiantan)
df_Wanliu_clean = cap_outliers_iqr(df_Wanliu)
df_Wanshouxigong_clean = cap_outliers_iqr(df_Wanshouxigong)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# Menggabungkan dataset yang sudah dibersihkan

# %%
df_all = pd.concat([
    df_Aotizhongxin_clean,
    df_Changping_clean,
    df_Dingling_clean,
    df_Dongsi_clean,
    df_Guanyuan_clean,
    df_Gucheng_clean,
    df_Huairou_clean,
    df_Nongzhanguan_clean,
    df_Shunyi_clean,
    df_Tiantan_clean,
    df_Wanliu_clean,
    df_Wanshouxigong_clean
], ignore_index=True)

# %% [markdown]
# Cek data hilang dan analisis deskriptif

# %%
print("data hilang : ", df_all.isna().sum().sum())
print("analisis deskriptif : \n", df_all.describe())
# Out:
# data hilang :  0
# analisis deskriptif :
#                    No           year          month            day  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.116943       1.177198       3.448707       8.800102
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean       11.500000      76.011595     101.498487      13.546944
# std         6.922195      68.179724      80.307238      14.268192
# ...

# %% [markdown]
# gabungkan data yang sudah siap dipakai ke file berbeda

# %%
df_all.to_csv('dashboard/clean_merged_dataset.csv', index=False)

# %% [markdown]
# cek data

# %%
df_all_clean = pd.read_csv("dashboard/clean_merged_dataset.csv")
print(df_all_clean.head())
print("data hilang : ", df_all_clean.isna().sum().sum())
# Out:
#     wd       station   No    year  month  day  hour  PM2.5  PM10   SO2   NO2  \
# 0  NNW  Aotizhongxin  1.0  2013.0    3.0  1.0   0.0    4.0   4.0   4.0   7.0
# 1    N  Aotizhongxin  2.0  2013.0    3.0  1.0   1.0    8.0   8.0   4.0   7.0
# 2  NNW  Aotizhongxin  3.0  2013.0    3.0  1.0   2.0    7.0   7.0   5.0  10.0
# 3   NW  Aotizhongxin  4.0  2013.0    3.0  1.0   3.0    6.0   6.0  11.0  11.0
# 4    N  Aotizhongxin  5.0  2013.0    3.0  1.0   4.0    3.0   3.0  12.0  12.0
#
#       CO    O3  TEMP    PRES  DEWP  RAIN  WSPM
# 0  300.0  77.0  -0.7  1023.0 -18.8   0.0  4.15
# 1  300.0  77.0  -1.1  1023.2 -18.2   0.0  4.15
# 2  300.0  73.0  -1.1  1023.5 -18.2   0.0  4.15
# 3  300.0  72.0  -1.4  1024.5 -19.4   0.0  3.10
# 4  300.0  72.0  -2.0  1025.2 -19.5   0.0  2.00
# data hilang :  0

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: agaimana korelasi antara suhu (TEMP) dengan tingkat polutan utama (PM2.5, PM10, SO2, NO2, CO, O3)?

# %%
def analyze_seasonal_correlations(df):
    # Assuming 'month' column exists in the dataframe instead of 'date_time'
    df['season'] = pd.cut(df['month'], 
                          bins=[0, 3, 6, 9, 12], 
                          labels=['Winter', 'Spring', 'Summer', 'Fall'])
    
    seasons = df['season'].unique()
    pollutants = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']
    
    seasonal_correlations = {season: {} for season in seasons}
    
    for season in seasons:
        season_data = df[df['season'] == season]
        for pollutant in pollutants:
            correlation, _ = stats.pearsonr(season_data['TEMP'], season_data[pollutant])
            seasonal_correlations[season][pollutant] = correlation
    
    
    plt.figure(figsize=(15, 8))
    x = np.arange(len(pollutants))
    width = 0.2
    
    for i, season in enumerate(seasons):
        plt.bar(x + i*width, list(seasonal_correlations[season].values()), 
                width, label=season)
    
    plt.xlabel('Pollutan')
    plt.ylabel('korelasi dengan temperatur')
    plt.title('Korelasi musim terhadap temperatur dan polutan')
    plt.xticks(x + width*1.5, pollutants, rotation=45)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
analyze_seasonal_correlations(df_all_clean)

# %% [markdown]
# Disini saya menggunakan musim untuk mengetahui pengaruh dari suhu terhadap pollutant

# %% [markdown]
# **Insight :**
# 1. O3 menunjukkan korelasi positif yang kuat dengan suhu, mengindikasikan peningkatan pembentukan ozon pada suhu yang lebih tinggi.
#  2. CO dan NO2 memiliki korelasi negatif dengan suhu, yang mungkin disebabkan oleh:
#        - Peningkatan penggunaan pemanas pada suhu rendah
#        - Kondisi inversi suhu yang menjebak polutan pada suhu rend    3. PM2.5 dan PM10 menunjukkan korelasi negatif lemah dengan suhu, menandakan pengaruh minimal suhu terhadap partikel tersuspensi.spensi.

# %% [markdown]
# ### Pertanyaan 2: Apakah ada perbedaan signifikan dalam tingkat polutan antara hari kerja dan akhir pekan?

# %%
df_all_clean['is_weekend'] = df_all_clean['day'].isin([6, 7]).map({True: 'Akhir Pekan', False: 'Hari Kerja'})

pollutants = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']

# Plotting
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.ravel()

for idx, pollutant in enumerate(pollutants):
    sns.boxplot(x='is_weekend', y=pollutant, data=df_all_clean, ax=axes[idx])
    axes[idx].set_title(f'{pollutant} - Hari Kerja vs Akhir Pekan')

plt.tight_layout()
plt.show()

# Statistical analysis
print("Analisis Statistik:")
for pollutant in pollutants:
    weekday_mean = df_all_clean[df_all_clean['is_weekend'] == 'Hari Kerja'][pollutant].mean()
    weekend_mean = df_all_clean[df_all_clean['is_weekend'] == 'Akhir Pekan'][pollutant].mean()
    percent_diff = ((weekend_mean - weekday_mean) / weekday_mean) * 100
    
    print(f"{pollutant}:")
    print(f"- Rata-rata hari kerja: {weekday_mean:.2f}")
    print(f"- Rata-rata akhir pekan: {weekend_mean:.2f}")
    print(f"- Perubahan: {percent_diff:.1f}%\n")
# Out:
# Analisis Statistik:
# PM2.5:
# - Rata-rata hari kerja: 75.54
# - Rata-rata akhir pekan: 82.70
# - Perubahan: 9.5%
#
# PM10:
# - Rata-rata hari kerja: 101.34
# - Rata-rata akhir pekan: 103.68
# - Perubahan: 2.3%
#
# SO2:
# - Rata-rata hari kerja: 13.47
# - Rata-rata akhir pekan: 14.58
# - Perubahan: 8.2%
#
# NO2:
# - Rata-rata hari kerja: 50.22
# - Rata-rata akhir pekan: 49.35
# - Perubahan: -1.7%
#
# CO:
# - Rata-rata hari kerja: 1131.25
# - Rata-rata akhir pekan: 1234.46
# - Perubahan: 9.1%
#
# O3:
# - Rata-rata hari kerja: 55.31
# - Rata-rata akhir pekan: 56.50
# - Perubahan: 2.1%

# %% [markdown]
# **Insight:**
# - Perubahan terilihat paling signifikan pada SO2, CO, dan PM2.5 kemungkinan karena adanya banyak kendaraan yang digunakan pada saat waktu weekend

# %% [markdown]
# ### Pertanyaan 3: Bagaimana tren tahunan tingkat rata-rata CO di berbagai kota dari 2013 hingga 2017 dan apakah ada pola umum yang terlihat?

# %%
yearly_co = df_all_clean.groupby(['year', 'station'])['CO'].mean().unstack()

# Plotting
plt.figure(figsize=(15, 10))
yearly_co.plot(marker="o")
plt.title("Rata-rata Tingkat CO per Tahun untuk Setiap Kota")
plt.xlabel("Tahun")
plt.ylabel("Rata-rata Tingkat CO (µg/m³)")
plt.xticks(yearly_co.index.astype(int), rotation=45)
plt.legend(title="Kota", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# Calculating total change for each city
for city in yearly_co.columns:
    total_change = yearly_co[city].iloc[-1] - yearly_co[city].iloc[0]
    print(f"Perubahan keseluruhan tingkat CO untuk {city} dari {yearly_co.index[0]} ke {yearly_co.index[-1]}: {total_change:.2f}")
# Out:
# Perubahan keseluruhan tingkat CO untuk Aotizhongxin dari 2013.0 ke 2017.0: 187.40
# Perubahan keseluruhan tingkat CO untuk Changping dari 2013.0 ke 2017.0: 227.62
# Perubahan keseluruhan tingkat CO untuk Dingling dari 2013.0 ke 2017.0: 65.31
# Perubahan keseluruhan tingkat CO untuk Dongsi dari 2013.0 ke 2017.0: 34.22
# Perubahan keseluruhan tingkat CO untuk Guanyuan dari 2013.0 ke 2017.0: 87.54
# Perubahan keseluruhan tingkat CO untuk Gucheng dari 2013.0 ke 2017.0: 173.23
# Perubahan keseluruhan tingkat CO untuk Huairou dari 2013.0 ke 2017.0: 150.50
# Perubahan keseluruhan tingkat CO untuk Nongzhanguan dari 2013.0 ke 2017.0: 116.37
# Perubahan keseluruhan tingkat CO untuk Shunyi dari 2013.0 ke 2017.0: 201.63
# Perubahan keseluruhan tingkat CO untuk Tiantan dari 2013.0 ke 2017.0: 152.60
# Perubahan keseluruhan tingkat CO untuk Wanliu dari 2013.0 ke 2017.0: 180.28
# Perubahan keseluruhan tingkat CO untuk Wanshouxigong dari 2013.0 ke 2017.0: 85.38

# %% [markdown]
# **Insight:**
# - Dari tren yang terlihat untuk CO terdapat penurunan pada tahun 2013 hingga 2016 tetapi terdapat kenaikan drastis di semua wilayah dari tahun 20136 sampai 2017.  Hal ini menunjukkan bahwa keberhasilan pada berbagai wilayah untuk mengurangi CO pada tahun 2013 hingga tahun 2016, tetapi karena kendaraan sangat merajalela, pada tahun 201   hingga 2017 semua wilayah mengalami kenaikan CO yang drastis. Kenaikan paling terasa di wilayah Wanliu. sedangkan Gucheng menjadi wilayah dengan jumlah CO tertinggi.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. konklusi korelasi temperatur terhadap polutan
#     - O3 meningkat pada suhu tinggi
#     - CO dan NO2 lebih tinggi pada suhu rendah
#     - PM2.5 dan PM10 kurang dipengaruhi suhu
# 2. konklusi perbedaan signifikan dalam tingkat polutan antara hari kerja dan akhir pekan
#    - NO2 menunjukkan penurunan di akhir pekan
#    - O3 cenderung lebih tinggi di akhir pekan
#    - PM2.5, CO, dan SO2 mengalami peningkatan cukup drastis hingga 7%
# 3. konklusi tren tahunan tingkat rata-rata CO di berbagai kota dari 2013 hingga 2017 dan apakah ada pola umum yang terlihat?
#     - Pada setiap tahunnya, CO tidak stabil dalam perubahannya
#     - Pada tahun 2016 CO di semua wilayah mengalami penurunan
#     - pada tahun 2017, CO di semua wilayah meningkat drastis dan menjadi tertinggi

# %% [markdown]
# **Implikasi Penelitian Lebih Lanjut:**
# 1. Analisis temporal jangka panjang untuk identifikasi tren
# 2. Studi korelasi dengan faktor sosio-ekonomi
# 3. Pengembangan model prediktif berbasis machine learningnging
